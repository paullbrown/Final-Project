# %%
import os
# Find the latest version of spark 3.x  from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.3.1'
spark_version = 'spark-3.4.0'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf $SPARK_VERSION-bin-hadoop3.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop3"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,058 kB]
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:12 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,776 kB]
# ...

# %%
from pyspark import SparkContext, SparkConf

# %%
from pyspark.sql import SparkSession

# %%
#Start Spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Final Project").getOrCreate()

# %%
from pyspark import SparkFiles

# %%
# Read in data from S3 Buckets
url20 = "https://cps-final-project-bucket.s3.us-east-2.amazonaws.com/metrics_collenrollpersist_schoollevel_20222_CLEAN_3+(2).csv"
spark.sparkContext.addFile(url20)
persist_3_df = spark.read.csv(SparkFiles.get("metrics_collenrollpersist_schoollevel_20222_CLEAN_3+(2).csv"), sep=",", header=True)

persist_3_df.show()
# Out:
# +---------+----------------------+------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+
# ...

# %%
persist_3_df = persist_3_df.toPandas()
persist_3_df.head()
# Out:
#   School_ID     Annualized School Name status Class of 2019 Graduates  \
# 0    400013  ASPIRA - EARLY COLLEGE HS   None                      75
# 1    400022                 CHIARTS HS   None                     133
# 2    400032          CICS - ELLISON HS   None                     101
# 3    400033            CICS - LONGWOOD   None                      87
# 4    400034        CICS - NORTHTOWN HS   None                     207
#
#   Class of 2019 Enrollments Class of 2019 Enrollment Pct  \
# 0                        30                           40
# 1                       114                         85.7
# 2                        62                         61.4
# 3                        44                         50.6
# 4                       151                         72.9
#
#   Class of 2019 # of Enrollments Persisting Class of 2019 Persistence Pct  \
# 0                                        18                            60
# ...

# %%
url22 = "https://cps-final-project-bucket.s3.us-east-2.amazonaws.com/metrics_cohortgraduationdropoutadjusted_schoollevel_2011to2019+(1).csv"
spark.sparkContext.addFile(url22)
grad_and_dropout_df = spark.read.csv(SparkFiles.get("metrics_cohortgraduationdropoutadjusted_schoollevel_2011to2019+(1).csv"), sep=",", header=True)

grad_and_dropout_df.show()
# Out:
# +---------+--------------------+-----------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |School ID|         School Name|Status as of 2019|2011 Grad. %|2012 Grad. %|2013 Grad. %|2014 Grad. %|2015 Grad. %|2016 Grad. %|2017 Grad. %|2018 Grad. %|2019 Grad. %|
# +---------+--------------------+-----------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |   400121|  ACERO - DE LA CRUZ|             null|        78.1|        79.5|        null|        null|        null|        null|        null|        null|        null|
# |   400085|   ACERO - GARCIA HS|             null|        75.5|        85.1|        89.5|        84.5|        89.2|        86.3|        87.3|        null|        null|
# ...

# %%
grad_and_dropout_df = grad_and_dropout_df.toPandas()
grad_and_dropout_df.head()
# Out:
#   School ID         School Name Status as of 2019 2011 Grad. % 2012 Grad. %  \
# 0    400121  ACERO - DE LA CRUZ              None         78.1         79.5
# 1    400085   ACERO - GARCIA HS              None         75.5         85.1
# 2    400149     ACERO - SOTO HS              None         83.9         71.4
# 3    610513        AIR FORCE HS              None         70.2         84.0
# 4    610524           ALCOTT HS              None         86.3         77.7
#
#   2013 Grad. % 2014 Grad. % 2015 Grad. % 2016 Grad. % 2017 Grad. %  \
# 0         None         None         None         None         None
# 1         89.5         84.5         89.2         86.3         87.3
# 2         None         None         None         None         None
# 3         86.1         86.7         81.9         83.7         None
# 4         87.1         81.3         84.9         92.1         None
#
#   2018 Grad. % 2019 Grad. %
# 0         None         None
# 1         None         None
# ...

# %%
# Read in data from S3 Buckets
url = "https://cps-final-project-bucket.s3.us-east-2.amazonaws.com/assessment_nwea_schoollevel_2019_attainment.csv"
spark.sparkContext.addFile(url)
attainment_df = spark.read.csv(SparkFiles.get("assessment_nwea_schoollevel_2019_attainment.csv"), sep=",", header=True)

attainment_df.show()
# Out:
# +---------+--------------------+-------+-------+-------+-----------------------+------------------------------+-----------------------------------------------------+--------------------------------------------------+-----------------------+------------------------------+----------------------------------------------------+--------------------------------------------------+-----------------------+------------------------------+----------------------------------------------------+--------------------------------------------------+-----------------------+------------------------------+----------------------------------------------------+--------------------------------------------------+
# ...

# %%
attainment_df = attainment_df.toPandas()

# %%
attainment_df.head()
# Out:
#   School ID         School Name  Network  Subject    Grade  \
# 0    400009  GLOBAL CITIZENSHIP  Charter  READING  Grade 8
# 1    400009  GLOBAL CITIZENSHIP  Charter     MATH  Grade 8
# 2    400011             LOCKE A  Charter  READING  Grade 8
# 3    400011             LOCKE A  Charter     MATH  Grade 8
# 4    400012             AMANDLA  Charter  READING  Grade 8
#
#   SY 2015-2016 # Students SY 2015-2016 Average RIT Score  \
# 0                      41                          221.9
# 1                      41                          231.1
# 2                    None                           None
# 3                    None                           None
# 4                      44                          213.4
#
#   SY 2015-2016  % At/Above National Average Performance  \
# 0                                               65.9
# 1                                               41.5
# 2                                               None
# ...

# %%
url10 = "https://cps-final-project-bucket.s3.us-east-2.amazonaws.com/metrics_attendance_clean3.csv"
spark.sparkContext.addFile(url10)
attendance2_df = spark.read.csv(SparkFiles.get("metrics_attendance_clean3.csv"), sep=",", header=True)
attendance2_df.show()
# Out:
# +---------+--------------------+---------+-----+-----+----+----+----+----+----+
# |School ID|         School Name|  Network|Group|Grade|2015|2016|2017|2018|2019|
# +---------+--------------------+---------+-----+-----+----+----+----+----+----+
# |   609771|              ABBOTT|     null|Grade|    8|null|null|null|null|null|
# |   400010|         ACE TECH HS|     null|Grade|    8|null|null|null|null|null|
# |   400153|ACERO - BRIGHTON ...|  Charter|Grade|    8|95.3|93.6|95.3|95.8|95.3|
# |   400101|    ACERO - CISNEROS|  Charter|Grade|    8|96.9|96.7|96.6|95.7|96.2|
# |   400120|    ACERO - CLEMENTE|  Charter|Grade|    8|95.3|94.8|95.0|95.6|95.6|
# |   400121|  ACERO - DE LA CRUZ|  Charter|Grade|    8|95.6|95.0|95.0|94.5|93.7|
# |   400081|ACERO - DE LAS CASAS|  Charter|Grade|    8|95.0|96.8|96.6|95.7|95.7|
# |   400082|     ACERO - FUENTES|  Charter|Grade|    8|96.7|95.4|96.8|95.2|96.4|
# |   400112|        ACERO - IDAR|  Charter|Grade|    8|97.2|96.0|95.8|95.2|96.1|
# ...

# %%
attendance2_df = attendance2_df.toPandas()
attendance2_df.head()
# Out:
#   School ID            School Name  Network  Group Grade  2015  2016  2017  \
# 0    609771                 ABBOTT     None  Grade     8  None  None  None
# 1    400010            ACE TECH HS     None  Grade     8  None  None  None
# 2    400153  ACERO - BRIGHTON PARK  Charter  Grade     8  95.3  93.6  95.3
# 3    400101       ACERO - CISNEROS  Charter  Grade     8  96.9  96.7  96.6
# 4    400120       ACERO - CLEMENTE  Charter  Grade     8  95.3  94.8  95.0
#
#    2018  2019
# 0  None  None
# 1  None  None
# 2  95.8  95.3
# 3  95.7  96.2
# 4  95.6  95.6

# %%
url6 = "https://cps-final-project-bucket.s3.us-east-2.amazonaws.com/metrics_fot_schoollevel_2022-1.csv"
spark.sparkContext.addFile(url6)
fot_df = spark.read.csv(SparkFiles.get("metrics_fot_schoollevel_2022-1.csv"), sep=",", header=True)

# %%
fot_df.show()
# Out:
# +---------+--------------------+---------------------+--------------------------------+---------------------+--------------------------------+---------------------+--------------------------------+---------------------+--------------------------------+---------------------+--------------------------------+
# |School ID|         School Name|SY 2019 On-Track Rate|SY 2019 Total Number of Freshmen|SY 2018 On-Track Rate|SY 2018 Total Number of Freshmen|SY 2017 On-Track Rate|SY 2017 Total Number of Freshmen|SY 2016 On-Track Rate|SY 2016 Total Number of Freshmen|SY 2015 On-Track Rate|SY 2015 Total Number of Freshmen|
# +---------+--------------------+---------------------+--------------------------------+---------------------+--------------------------------+---------------------+--------------------------------+---------------------+--------------------------------+---------------------+--------------------------------+
# ...

# %%
fot_df = fot_df.toPandas()

# %%
fot_df.head()
# Out:
#   School ID            School Name SY 2019 On-Track Rate  \
# 0    610513           AIR FORCE HS                  88.9
# 1    610524              ALCOTT HS                  90.0
# 2    609695            AMUNDSEN HS                  92.4
# 3    400018  AUSTIN BUS & ENTRP HS                  None
# 4    610518          AUSTIN CCA HS                  87.9
#
#   SY 2019 Total Number of Freshmen SY 2018 On-Track Rate  \
# 0                               54                  90.6
# 1                              100                  90.7
# 2                              369                  92.4
# 3                             None                  None
# 4                               58                  76.9
#
#   SY 2018 Total Number of Freshmen SY 2017 On-Track Rate  \
# 0                               32                  87.4
# 1                               86                  77.6
# 2                              327                  90.0
# ...

# %%
url8 = "https://cps-final-project-bucket.s3.us-east-2.amazonaws.com/assessment_nwea_schoollevel_2019_growth.csv"
spark.sparkContext.addFile(url8)
growth_df = spark.read.csv(SparkFiles.get("assessment_nwea_schoollevel_2019_growth.csv"), sep=",", header=True)
growth_df.show()
# Out:
# +---------+--------------------+-------+-------+-------+---------------------+--------------------------------------+----------------------------------------+-------------------------------+------------------------------------------------------+----------------------------------------------+---------------------+--------------------------------------+----------------------------------------+-------------------------------+------------------------------------------------------+----------------------------------------------+---------------------+--------------------------------------+----------------------------------------+-------------------------------+------------------------------------------------------+----------------------------------------------+---------------------+--------------------------------------+----------------------------------------+-------------------------------+------------------------------------------------------+---------------------------------------------
# ...

# %%
growth_df = growth_df.toPandas()
growth_df.head()
# Out:
#   School ID         School Name  Network  Subject    Grade  \
# 0    400009  GLOBAL CITIZENSHIP  Charter  READING  Grade 8
# 1    400009  GLOBAL CITIZENSHIP  Charter     MATH  Grade 8
# 2    400011             LOCKE A  Charter  READING  Grade 8
# 3    400011             LOCKE A  Charter     MATH  Grade 8
# 4    400012             AMANDLA  Charter  READING  Grade 8
#
#   SY 2015-2016 # Tested SY 2015-2016 Average Pretest RIT Score  \
# 0                    41                                  216.4
# 1                    41                                  223.8
# 2                  None                                   None
# 3                  None                                   None
# 4                    38                                    213
#
#   SY 2015-2016 Average Posttest RIT Score  SY 2015-2016 Average RIT Growth  \
# 0                                    221.9                             5.5
# 1                                    231.1                             7.3
# ...

# %%
url12 = "https://cps-final-project-bucket.s3.us-east-2.amazonaws.com/metrics_collenrollpersist_schoollevel_20222_CLEAN_3.csv"
spark.sparkContext.addFile(url12)
schoollevel_persist_df3 = spark.read.csv(SparkFiles.get("metrics_collenrollpersist_schoollevel_20222_CLEAN_3.csv"), sep=",", header=True)
schoollevel_persist_df3.show()
# Out:
# +---------+----------------------+------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+-----------------------+-------------------------+----------------------------+-----------------------------------------+-----------------------------+
# ...

# %%
schoollevel_persist_df3 = schoollevel_persist_df3.toPandas()
schoollevel_persist_df3.head()
# Out:
#   School_ID     Annualized School Name status Class of 2019 Graduates  \
# 0    400013  ASPIRA - EARLY COLLEGE HS   None                      75
# 1    400022                 CHIARTS HS   None                     133
# 2    400032          CICS - ELLISON HS   None                     101
# 3    400033            CICS - LONGWOOD   None                      87
# 4    400034        CICS - NORTHTOWN HS   None                     207
#
#   Class of 2019 Enrollments Class of 2019 Enrollment Pct  \
# 0                        30                           40
# 1                       114                         85.7
# 2                        62                         61.4
# 3                        44                         50.6
# 4                       151                         72.9
#
#   Class of 2019 # of Enrollments Persisting Class of 2019 Persistence Pct  \
# 0                                        18                            60
# ...
